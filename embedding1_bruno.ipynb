# %%
#importar datasets de proves y splitter alemany
# !pip install datasets evaluate --upgrade
# !python -m spacy download de_core_news_sm

# %%
import re
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
import spacy
import datasets
import torchtext
import tqdm
import evaluate

# %% [markdown]
# Creem un dataset a partir del txt que serà un diccionari amb les claus dels idiomes (en i de) i com a valor una llista de les frases traduïdes en ordre

# %%
def eliminar_ccby(linea):
    indice_ccby = linea.find("CC-BY")
    if indice_ccby != -1:
        return linea[:indice_ccby]
    return linea

def separar_frases(linea):
    patron = r'(.+?[.!?])\s+([^A-Z]?[\s]+)?(.+)?'
    coincidencias = re.match(patron, linea)
    if coincidencias:
        frase1 = coincidencias.group(1)
        frase2 = coincidencias.group(3)
        return frase1.strip(), frase2.strip() if frase2 else None
    else:
        return None, None

def make_dataset(archivo_entrada):
    #english,deutsch = [],[]
    dataset = []
    with open(archivo_entrada, 'r') as f_in:
        for linea in f_in:
            linea_clean = eliminar_ccby(linea)
            a,b = separar_frases(linea_clean)
            dataset.append({'en':a,'de':b})
            #english.append(a)
            #deutsch.append(b)
    #dataset = {'en':english,'de':deutsch}
    return dataset

archivo_entrada = 'deu.txt'
data = make_dataset(archivo_entrada)

# %%
print(data[:10])
# Out:
# [{'en': 'Go.', 'de': 'Geh.'}, {'en': 'Hi.', 'de': 'Hallo!'}, {'en': 'Hi.', 'de': 'Grüß Gott!'}, {'en': 'Run!', 'de': 'Lauf!'}, {'en': 'Run.', 'de': 'Lauf!'}, {'en': 'Wow!', 'de': 'Potzdonner!'}, {'en': 'Wow!', 'de': 'Donnerwetter!'}, {'en': 'Duck!', 'de': 'Kopf runter!'}, {'en': 'Fire!', 'de': 'Feuer!'}, {'en': 'Help!', 'de': 'Hilfe!'}]

# %% [markdown]
# Importem splitters d'anglés i alemany

# %%
en_nlp = spacy.load("en_core_web_sm")
de_nlp = spacy.load("de_core_news_sm")

# %%
string = "What a lovely day it is today!"
[token.text for token in en_nlp.tokenizer(string)]
# Out:
# ['What', 'a', 'lovely', 'day', 'it', 'is', 'today', '!']

# %% [markdown]
# Millorem funció de split tenint en compte les majúscules

# %% [markdown]
# Para cada par de oraciones añadimos a más su split correspondiente con el incio y fin de frase

# %%
def tokenize_example(data, en_nlp, de_nlp, max_length, lower, sos_token, eos_token):
    for i in range(len(data)):
        en_tokens = [token.text for token in en_nlp.tokenizer(data[i]["en"])][:max_length]
        de_tokens = [token.text for token in de_nlp.tokenizer(data[i]["de"])][:max_length]
        if lower:
            en_tokens = [token.lower() for token in en_tokens]
            de_tokens = [token.lower() for token in de_tokens]
        en_tokens = [sos_token] + en_tokens + [eos_token]
        de_tokens = [sos_token] + de_tokens + [eos_token]
        data[i]['en_tokens'] = en_tokens
        data[i]['de_tokens'] = de_tokens
    return data

# %%
train = data[:1000]
max_length = 1000
lower = True
sos_token = "<sos>"
eos_token = "<eos>"

fn_kwargs = {
    "example": train,
    "en_nlp": en_nlp,
    "de_nlp": de_nlp,
    "max_length": max_length,
    "lower": lower,
    "sos_token": sos_token,
    "eos_token": eos_token,
}
inputs = [train,en_nlp,de_nlp,max_length,lower,sos_token,eos_token]

# %% [markdown]
# sos = start of sentence,
# eos = end of sentence,
# unk = unknown,
# pad = padding

# %%
train = tokenize_example(*inputs)
train[0]
# Out:
# {'en': 'Go.',
#  'de': 'Geh.',
#  'en_tokens': ['<sos>', 'go', '.', '<eos>'],
#  'de_tokens': ['<sos>', 'geh', '.', '<eos>']}

# %%
min_freq = 2
unk_token = "<unk>"
pad_token = "<pad>"

special_tokens = [
    unk_token,
    pad_token,
    sos_token,
    eos_token,
]


all_en_tokens, all_de_tokens = [], []
for frase in train:
    all_en_tokens.append(frase['en_tokens'])
    all_de_tokens.append(frase['de_tokens'])

en_vocab = torchtext.vocab.build_vocab_from_iterator(
    all_en_tokens,
    min_freq=min_freq,
    specials=special_tokens,
)

de_vocab = torchtext.vocab.build_vocab_from_iterator(
    all_de_tokens,
    min_freq=min_freq,
    specials=special_tokens,
)

# %%
words_en, words_de = en_vocab.get_itos(), de_vocab.get_itos()
len(words_en), len(words_de)
# Out:
# (262, 297)

# %%
assert en_vocab[unk_token] == de_vocab[unk_token]
assert en_vocab[pad_token] == de_vocab[pad_token]

unk_index = en_vocab[unk_token]
pad_index = en_vocab[pad_token]

en_vocab.set_default_index(unk_index)
de_vocab.set_default_index(unk_index)

# %%
"man" in words_en
# Out:
# True

# %%
def numericalize_example(data, en_vocab, de_vocab):
    for i in range(len(data)):
        en_ids = en_vocab.lookup_indices(data[i]["en_tokens"])
        de_ids = de_vocab.lookup_indices(data[i]["de_tokens"])
        data[i]['en_ids'] = en_ids
        data[i]['de_ids'] = de_ids
    return data

# %%
train = numericalize_example(train, en_vocab, de_vocab)
train
# Out:
# [{'en': 'Go.',
#   'de': 'Geh.',
#   'en_tokens': ['<sos>', 'go', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', '.', '<eos>'],
#   'en_ids': [2, 10, 4, 3],
#   'de_ids': [2, 27, 4, 3]},
#  {'en': 'Hi.',
#   'de': 'Hallo!',
#   'en_tokens': ['<sos>', 'hi', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hallo', '!', '<eos>'],
#   'en_ids': [2, 141, 4, 3],
#   'de_ids': [2, 99, 5, 3]},
#  {'en': 'Hi.',
#   'de': 'Grüß Gott!',
#   'en_tokens': ['<sos>', 'hi', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'grüß', 'gott', '!', '<eos>'],
#   'en_ids': [2, 141, 4, 3],
#   'de_ids': [2, 0, 0, 5, 3]},
#  {'en': 'Run!',
#   'de': 'Lauf!',
#   'en_tokens': ['<sos>', 'run', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'lauf', '!', '<eos>'],
#   'en_ids': [2, 61, 7, 3],
#   'de_ids': [2, 146, 5, 3]},
#  {'en': 'Run.',
#   'de': 'Lauf!',
#   'en_tokens': ['<sos>', 'run', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'lauf', '!', '<eos>'],
#   'en_ids': [2, 61, 4, 3],
#   'de_ids': [2, 146, 5, 3]},
#  {'en': 'Wow!',
#   'de': 'Potzdonner!',
#   'en_tokens': ['<sos>', 'wow', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'potzdonner', '!', '<eos>'],
#   'en_ids': [2, 259, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Wow!',
#   'de': 'Donnerwetter!',
#   'en_tokens': ['<sos>', 'wow', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'donnerwetter', '!', '<eos>'],
#   'en_ids': [2, 259, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Duck!',
#   'de': 'Kopf runter!',
#   'en_tokens': ['<sos>', 'duck', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'kopf', 'runter', '!', '<eos>'],
#   'en_ids': [2, 0, 7, 3],
#   'de_ids': [2, 240, 112, 5, 3]},
#  {'en': 'Fire!',
#   'de': 'Feuer!',
#   'en_tokens': ['<sos>', 'fire', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'feuer', '!', '<eos>'],
#   'en_ids': [2, 186, 7, 3],
#   'de_ids': [2, 132, 5, 3]},
#  {'en': 'Help!',
#   'de': 'Hilfe!',
#   'en_tokens': ['<sos>', 'help', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'hilfe', '!', '<eos>'],
#   'en_ids': [2, 38, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Help!',
#   'de': 'Zu Hülf!',
#   'en_tokens': ['<sos>', 'help', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'zu', 'hülf', '!', '<eos>'],
#   'en_ids': [2, 38, 7, 3],
#   'de_ids': [2, 25, 0, 5, 3]},
#  {'en': 'Hide.',
#   'de': 'Versteck dich!',
#   'en_tokens': ['<sos>', 'hide', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'versteck', 'dich', '!', '<eos>'],
#   'en_ids': [2, 202, 4, 3],
#   'de_ids': [2, 0, 12, 5, 3]},
#  {'en': 'Hide.',
#   'de': 'Versteckt euch!',
#   'en_tokens': ['<sos>', 'hide', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'versteckt', 'euch', '!', '<eos>'],
#   'en_ids': [2, 202, 4, 3],
#   'de_ids': [2, 178, 50, 5, 3]},
#  {'en': 'Stay.',
#   'de': 'Bleib!',
#   'en_tokens': ['<sos>', 'stay', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'bleib', '!', '<eos>'],
#   'en_ids': [2, 235, 4, 3],
#   'de_ids': [2, 194, 5, 3]},
#  {'en': 'Stop!',
#   'de': 'Stopp!',
#   'en_tokens': ['<sos>', 'stop', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'stopp', '!', '<eos>'],
#   'en_ids': [2, 62, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Stop!',
#   'de': 'Anhalten!',
#   'en_tokens': ['<sos>', 'stop', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'anhalten', '!', '<eos>'],
#   'en_ids': [2, 62, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Wait!',
#   'de': 'Warte!',
#   'en_tokens': ['<sos>', 'wait', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'warte', '!', '<eos>'],
#   'en_ids': [2, 73, 7, 3],
#   'de_ids': [2, 88, 5, 3]},
#  {'en': 'Wait.',
#   'de': 'Warte.',
#   'en_tokens': ['<sos>', 'wait', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'warte', '.', '<eos>'],
#   'en_ids': [2, 73, 4, 3],
#   'de_ids': [2, 88, 4, 3]},
#  {'en': 'Begin.',
#   'de': 'Fang an.',
#   'en_tokens': ['<sos>', 'begin', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'fang', 'an', '.', '<eos>'],
#   'en_ids': [2, 0, 4, 3],
#   'de_ids': [2, 97, 35, 4, 3]},
#  {'en': 'Do it.',
#   'de': 'Mache es!',
#   'en_tokens': ['<sos>', 'do', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mache', 'es', '!', '<eos>'],
#   'en_ids': [2, 26, 6, 4, 3],
#   'de_ids': [2, 247, 7, 5, 3]},
#  {'en': 'Do it.',
#   'de': 'Tue es.',
#   'en_tokens': ['<sos>', 'do', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'tue', 'es', '.', '<eos>'],
#   'en_ids': [2, 26, 6, 4, 3],
#   'de_ids': [2, 279, 7, 4, 3]},
#  {'en': 'Go on.',
#   'de': 'Mach weiter.',
#   'en_tokens': ['<sos>', 'go', 'on', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'weiter', '.', '<eos>'],
#   'en_ids': [2, 10, 40, 4, 3],
#   'de_ids': [2, 17, 185, 4, 3]},
#  {'en': 'Hello!',
#   'de': 'Hallo!',
#   'en_tokens': ['<sos>', 'hello', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'hallo', '!', '<eos>'],
#   'en_ids': [2, 140, 7, 3],
#   'de_ids': [2, 99, 5, 3]},
#  {'en': 'Hello!',
#   'de': 'Sers!',
#   'en_tokens': ['<sos>', 'hello', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'sers', '!', '<eos>'],
#   'en_ids': [2, 140, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Hello.',
#   'de': 'Hallo!',
#   'en_tokens': ['<sos>', 'hello', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hallo', '!', '<eos>'],
#   'en_ids': [2, 140, 4, 3],
#   'de_ids': [2, 99, 5, 3]},
#  {'en': 'Hurry!',
#   'de': 'Beeil dich!',
#   'en_tokens': ['<sos>', 'hurry', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'beeil', 'dich', '!', '<eos>'],
#   'en_ids': [2, 80, 7, 3],
#   'de_ids': [2, 119, 12, 5, 3]},
#  {'en': 'Hurry!',
#   'de': 'Schnell!',
#   'en_tokens': ['<sos>', 'hurry', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'schnell', '!', '<eos>'],
#   'en_ids': [2, 80, 7, 3],
#   'de_ids': [2, 264, 5, 3]},
#  {'en': 'I hid.',
#   'de': 'Ich versteckte mich.',
#   'en_tokens': ['<sos>', 'i', 'hid', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'versteckte', 'mich', '.', '<eos>'],
#   'en_ids': [2, 5, 98, 4, 3],
#   'de_ids': [2, 6, 282, 18, 4, 3]},
#  {'en': 'I hid.',
#   'de': 'Ich habe mich versteckt.',
#   'en_tokens': ['<sos>', 'i', 'hid', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'mich', 'versteckt', '.', '<eos>'],
#   'en_ids': [2, 5, 98, 4, 3],
#   'de_ids': [2, 6, 14, 18, 178, 4, 3]},
#  {'en': 'I ran.',
#   'de': 'Ich rannte.',
#   'en_tokens': ['<sos>', 'i', 'ran', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'rannte', '.', '<eos>'],
#   'en_ids': [2, 5, 60, 4, 3],
#   'de_ids': [2, 6, 110, 4, 3]},
#  {'en': 'I see.',
#   'de': 'Ich verstehe.',
#   'en_tokens': ['<sos>', 'i', 'see', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'verstehe', '.', '<eos>'],
#   'en_ids': [2, 5, 87, 4, 3],
#   'de_ids': [2, 6, 179, 4, 3]},
#  {'en': 'I see.',
#   'de': 'Aha.',
#   'en_tokens': ['<sos>', 'i', 'see', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'aha', '.', '<eos>'],
#   'en_ids': [2, 5, 87, 4, 3],
#   'de_ids': [2, 186, 4, 3]},
#  {'en': 'I try.',
#   'de': 'Ich versuche es.',
#   'en_tokens': ['<sos>', 'i', 'try', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'versuche', 'es', '.', '<eos>'],
#   'en_ids': [2, 5, 46, 4, 3],
#   'de_ids': [2, 6, 0, 7, 4, 3]},
#  {'en': 'I try.',
#   'de': 'Ich probiere es.',
#   'en_tokens': ['<sos>', 'i', 'try', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'probiere', 'es', '.', '<eos>'],
#   'en_ids': [2, 5, 46, 4, 3],
#   'de_ids': [2, 6, 0, 7, 4, 3]},
#  {'en': 'I won!',
#   'de': 'Ich hab gewonnen!',
#   'en_tokens': ['<sos>', 'i', 'won', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'hab', 'gewonnen', '!', '<eos>'],
#   'en_ids': [2, 5, 53, 7, 3],
#   'de_ids': [2, 6, 226, 37, 5, 3]},
#  {'en': 'I won!',
#   'de': 'Ich habe gewonnen!',
#   'en_tokens': ['<sos>', 'i', 'won', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'gewonnen', '!', '<eos>'],
#   'en_ids': [2, 5, 53, 7, 3],
#   'de_ids': [2, 6, 14, 37, 5, 3]},
#  {'en': 'I won.',
#   'de': 'Ich habe gewonnen.',
#   'en_tokens': ['<sos>', 'i', 'won', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'gewonnen', '.', '<eos>'],
#   'en_ids': [2, 5, 53, 4, 3],
#   'de_ids': [2, 6, 14, 37, 4, 3]},
#  {'en': 'Oh no!',
#   'de': 'Oh, Nein!',
#   'en_tokens': ['<sos>', 'oh', 'no', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'oh', ',', 'nein', '!', '<eos>'],
#   'en_ids': [2, 0, 59, 7, 3],
#   'de_ids': [2, 0, 53, 251, 5, 3]},
#  {'en': 'Relax.',
#   'de': 'Entspann dich.',
#   'en_tokens': ['<sos>', 'relax', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'entspann', 'dich', '.', '<eos>'],
#   'en_ids': [2, 0, 4, 3],
#   'de_ids': [2, 130, 12, 4, 3]},
#  {'en': 'Shoot!',
#   'de': 'Feuer!',
#   'en_tokens': ['<sos>', 'shoot', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'feuer', '!', '<eos>'],
#   'en_ids': [2, 228, 7, 3],
#   'de_ids': [2, 132, 5, 3]},
#  {'en': 'Shoot!',
#   'de': 'Schieß!',
#   'en_tokens': ['<sos>', 'shoot', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'schieß', '!', '<eos>'],
#   'en_ids': [2, 228, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Smile.',
#   'de': 'Lächeln!',
#   'en_tokens': ['<sos>', 'smile', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'lächeln', '!', '<eos>'],
#   'en_ids': [2, 0, 4, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Sorry?',
#   'de': 'Entschuldigung?',
#   'en_tokens': ['<sos>', 'sorry', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'entschuldigung', '?', '<eos>'],
#   'en_ids': [2, 111, 14, 3],
#   'de_ids': [2, 63, 13, 3]},
#  {'en': 'Ask me.',
#   'de': 'Frag mich!',
#   'en_tokens': ['<sos>', 'ask', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'frag', 'mich', '!', '<eos>'],
#   'en_ids': [2, 41, 15, 4, 3],
#   'de_ids': [2, 66, 18, 5, 3]},
#  {'en': 'Ask me.',
#   'de': 'Fragt mich!',
#   'en_tokens': ['<sos>', 'ask', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'fragt', 'mich', '!', '<eos>'],
#   'en_ids': [2, 41, 15, 4, 3],
#   'de_ids': [2, 210, 18, 5, 3]},
#  {'en': 'Ask me.',
#   'de': 'Fragen Sie mich!',
#   'en_tokens': ['<sos>', 'ask', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'fragen', 'sie', 'mich', '!', '<eos>'],
#   'en_ids': [2, 41, 15, 4, 3],
#   'de_ids': [2, 209, 10, 18, 5, 3]},
#  {'en': 'Attack!',
#   'de': 'Angriff!',
#   'en_tokens': ['<sos>', 'attack', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'angriff', '!', '<eos>'],
#   'en_ids': [2, 169, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Attack!',
#   'de': 'Attacke!',
#   'en_tokens': ['<sos>', 'attack', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'attacke', '!', '<eos>'],
#   'en_ids': [2, 169, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Buy it.',
#   'de': 'Kauf’s!',
#   'en_tokens': ['<sos>', 'buy', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'kauf', '’s', '!', '<eos>'],
#   'en_ids': [2, 175, 6, 4, 3],
#   'de_ids': [2, 0, 49, 5, 3]},
#  {'en': 'Cheers!',
#   'de': 'Zum Wohl!',
#   'en_tokens': ['<sos>', 'cheers', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'zum', 'wohl', '!', '<eos>'],
#   'en_ids': [2, 0, 7, 3],
#   'de_ids': [2, 0, 294, 5, 3]},
#  {'en': 'Eat it.',
#   'de': 'Iss es.',
#   'en_tokens': ['<sos>', 'eat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'iss', 'es', '.', '<eos>'],
#   'en_ids': [2, 76, 6, 4, 3],
#   'de_ids': [2, 101, 7, 4, 3]},
#  {'en': 'Eat up.',
#   'de': 'Iss fertig!',
#   'en_tokens': ['<sos>', 'eat', 'up', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'iss', 'fertig', '!', '<eos>'],
#   'en_ids': [2, 76, 16, 4, 3],
#   'de_ids': [2, 101, 205, 5, 3]},
#  {'en': 'Eat up.',
#   'de': 'Iss auf.',
#   'en_tokens': ['<sos>', 'eat', 'up', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'iss', 'auf', '.', '<eos>'],
#   'en_ids': [2, 76, 16, 4, 3],
#   'de_ids': [2, 101, 19, 4, 3]},
#  {'en': 'Eat up.',
#   'de': 'Iss auf!',
#   'en_tokens': ['<sos>', 'eat', 'up', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'iss', 'auf', '!', '<eos>'],
#   'en_ids': [2, 76, 16, 4, 3],
#   'de_ids': [2, 101, 19, 5, 3]},
#  {'en': 'Exhale.',
#   'de': 'Ausatmen!',
#   'en_tokens': ['<sos>', 'exhale', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ausatmen', '!', '<eos>'],
#   'en_ids': [2, 0, 4, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Freeze!',
#   'de': 'Keine Bewegung!',
#   'en_tokens': ['<sos>', 'freeze', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'keine', 'bewegung', '!', '<eos>'],
#   'en_ids': [2, 191, 7, 3],
#   'de_ids': [2, 0, 0, 5, 3]},
#  {'en': 'Freeze!',
#   'de': 'Stehenbleiben!',
#   'en_tokens': ['<sos>', 'freeze', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'stehenbleiben', '!', '<eos>'],
#   'en_ids': [2, 191, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Go now.',
#   'de': 'Geh jetzt!',
#   'en_tokens': ['<sos>', 'go', 'now', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'jetzt', '!', '<eos>'],
#   'en_ids': [2, 10, 106, 4, 3],
#   'de_ids': [2, 27, 51, 5, 3]},
#  {'en': 'Got it!',
#   'de': 'Verstanden!',
#   'en_tokens': ['<sos>', 'got', 'it', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'verstanden', '!', '<eos>'],
#   'en_ids': [2, 30, 6, 7, 3],
#   'de_ids': [2, 177, 5, 3]},
#  {'en': 'Got it!',
#   'de': 'Ich hab’s!',
#   'en_tokens': ['<sos>', 'got', 'it', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'hab', '’s', '!', '<eos>'],
#   'en_ids': [2, 30, 6, 7, 3],
#   'de_ids': [2, 6, 226, 49, 5, 3]},
#  {'en': 'Got it!',
#   'de': 'Aha!',
#   'en_tokens': ['<sos>', 'got', 'it', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'aha', '!', '<eos>'],
#   'en_ids': [2, 30, 6, 7, 3],
#   'de_ids': [2, 186, 5, 3]},
#  {'en': 'Got it?',
#   'de': 'Kapiert?',
#   'en_tokens': ['<sos>', 'got', 'it', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'kapiert', '?', '<eos>'],
#   'en_ids': [2, 30, 6, 14, 3],
#   'de_ids': [2, 0, 13, 3]},
#  {'en': 'Got it?',
#   'de': 'Verstanden?',
#   'en_tokens': ['<sos>', 'got', 'it', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'verstanden', '?', '<eos>'],
#   'en_ids': [2, 30, 6, 14, 3],
#   'de_ids': [2, 177, 13, 3]},
#  {'en': 'Got it?',
#   'de': 'Einverstanden?',
#   'en_tokens': ['<sos>', 'got', 'it', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'einverstanden', '?', '<eos>'],
#   'en_ids': [2, 30, 6, 14, 3],
#   'de_ids': [2, 95, 13, 3]},
#  {'en': 'He ran.',
#   'de': 'Er rannte.',
#   'en_tokens': ['<sos>', 'he', 'ran', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'er', 'rannte', '.', '<eos>'],
#   'en_ids': [2, 18, 60, 4, 3],
#   'de_ids': [2, 20, 110, 4, 3]},
#  {'en': 'He ran.',
#   'de': 'Er lief.',
#   'en_tokens': ['<sos>', 'he', 'ran', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'er', 'lief', '.', '<eos>'],
#   'en_ids': [2, 18, 60, 4, 3],
#   'de_ids': [2, 20, 0, 4, 3]},
#  {'en': 'Hop in.',
#   'de': 'Mach mit!',
#   'en_tokens': ['<sos>', 'hop', 'in', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'mit', '!', '<eos>'],
#   'en_ids': [2, 203, 50, 4, 3],
#   'de_ids': [2, 17, 74, 5, 3]},
#  {'en': 'Hop in.',
#   'de': 'Spring rein!',
#   'en_tokens': ['<sos>', 'hop', 'in', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'spring', 'rein', '!', '<eos>'],
#   'en_ids': [2, 203, 50, 4, 3],
#   'de_ids': [2, 0, 158, 5, 3]},
#  {'en': 'Hug me.',
#   'de': 'Drück mich!',
#   'en_tokens': ['<sos>', 'hug', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'drück', 'mich', '!', '<eos>'],
#   'en_ids': [2, 44, 15, 4, 3],
#   'de_ids': [2, 128, 18, 5, 3]},
#  {'en': 'Hug me.',
#   'de': 'Nimm mich in den Arm!',
#   'en_tokens': ['<sos>', 'hug', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'nimm', 'mich', 'in', 'den', 'arm', '!', '<eos>'],
#   'en_ids': [2, 44, 15, 4, 3],
#   'de_ids': [2, 60, 18, 43, 126, 0, 5, 3]},
#  {'en': 'Hug me.',
#   'de': 'Umarme mich!',
#   'en_tokens': ['<sos>', 'hug', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'umarme', 'mich', '!', '<eos>'],
#   'en_ids': [2, 44, 15, 4, 3],
#   'de_ids': [2, 281, 18, 5, 3]},
#  {'en': 'I care.',
#   'de': 'Mir ist es wichtig.',
#   'en_tokens': ['<sos>', 'i', 'care', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mir', 'ist', 'es', 'wichtig', '.', '<eos>'],
#   'en_ids': [2, 5, 0, 4, 3],
#   'de_ids': [2, 15, 11, 7, 0, 4, 3]},
#  {'en': 'I fell.',
#   'de': 'Ich fiel.',
#   'en_tokens': ['<sos>', 'i', 'fell', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'fiel', '.', '<eos>'],
#   'en_ids': [2, 5, 43, 4, 3],
#   'de_ids': [2, 6, 64, 4, 3]},
#  {'en': 'I fell.',
#   'de': 'Ich fiel hin.',
#   'en_tokens': ['<sos>', 'i', 'fell', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'fiel', 'hin', '.', '<eos>'],
#   'en_ids': [2, 5, 43, 4, 3],
#   'de_ids': [2, 6, 64, 59, 4, 3]},
#  {'en': 'I fell.',
#   'de': 'Ich stürzte.',
#   'en_tokens': ['<sos>', 'i', 'fell', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'stürzte', '.', '<eos>'],
#   'en_ids': [2, 5, 43, 4, 3],
#   'de_ids': [2, 6, 0, 4, 3]},
#  {'en': 'I fell.',
#   'de': 'Ich bin hingefallen.',
#   'en_tokens': ['<sos>', 'i', 'fell', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'hingefallen', '.', '<eos>'],
#   'en_ids': [2, 5, 43, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': 'I fell.',
#   'de': 'Ich bin gestürzt.',
#   'en_tokens': ['<sos>', 'i', 'fell', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'gestürzt', '.', '<eos>'],
#   'en_ids': [2, 5, 43, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': 'I fled.',
#   'de': 'Ich flüchtete.',
#   'en_tokens': ['<sos>', 'i', 'fled', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'flüchtete', '.', '<eos>'],
#   'en_ids': [2, 5, 188, 4, 3],
#   'de_ids': [2, 6, 0, 4, 3]},
#  {'en': 'I fled.',
#   'de': 'Ich bin geflüchtet.',
#   'en_tokens': ['<sos>', 'i', 'fled', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'geflüchtet', '.', '<eos>'],
#   'en_ids': [2, 5, 188, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': 'I know.',
#   'de': 'Ich weiß.',
#   'en_tokens': ['<sos>', 'i', 'know', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'weiß', '.', '<eos>'],
#   'en_ids': [2, 5, 0, 4, 3],
#   'de_ids': [2, 6, 0, 4, 3]},
#  {'en': 'I lied.',
#   'de': 'Ich habe gelogen.',
#   'en_tokens': ['<sos>', 'i', 'lied', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'gelogen', '.', '<eos>'],
#   'en_ids': [2, 5, 143, 4, 3],
#   'de_ids': [2, 6, 14, 217, 4, 3]},
#  {'en': 'I lost.',
#   'de': 'Ich habe verloren.',
#   'en_tokens': ['<sos>', 'i', 'lost', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'verloren', '.', '<eos>'],
#   'en_ids': [2, 5, 17, 4, 3],
#   'de_ids': [2, 6, 14, 45, 4, 3]},
#  {'en': 'I paid.',
#   'de': 'Ich habe bezahlt.',
#   'en_tokens': ['<sos>', 'i', 'paid', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'bezahlt', '.', '<eos>'],
#   'en_ids': [2, 5, 147, 4, 3],
#   'de_ids': [2, 6, 14, 0, 4, 3]},
#  {'en': 'I paid.',
#   'de': 'Ich zahlte.',
#   'en_tokens': ['<sos>', 'i', 'paid', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'zahlte', '.', '<eos>'],
#   'en_ids': [2, 5, 147, 4, 3],
#   'de_ids': [2, 6, 0, 4, 3]},
#  {'en': 'I pass.',
#   'de': 'Ich passe.',
#   'en_tokens': ['<sos>', 'i', 'pass', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'passe', '.', '<eos>'],
#   'en_ids': [2, 5, 0, 4, 3],
#   'de_ids': [2, 6, 0, 4, 3]},
#  {'en': 'I sang.',
#   'de': 'Ich sang.',
#   'en_tokens': ['<sos>', 'i', 'sang', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'sang', '.', '<eos>'],
#   'en_ids': [2, 5, 226, 4, 3],
#   'de_ids': [2, 6, 258, 4, 3]},
#  {'en': 'I spit.',
#   'de': 'Ich spuckte.',
#   'en_tokens': ['<sos>', 'i', 'spit', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'spuckte', '.', '<eos>'],
#   'en_ids': [2, 5, 112, 4, 3],
#   'de_ids': [2, 6, 276, 4, 3]},
#  {'en': 'I spit.',
#   'de': 'Ich habe gespuckt.',
#   'en_tokens': ['<sos>', 'i', 'spit', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'gespuckt', '.', '<eos>'],
#   'en_ids': [2, 5, 112, 4, 3],
#   'de_ids': [2, 6, 14, 223, 4, 3]},
#  {'en': 'I swim.',
#   'de': 'Ich schwimme.',
#   'en_tokens': ['<sos>', 'i', 'swim', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'schwimme', '.', '<eos>'],
#   'en_ids': [2, 5, 239, 4, 3],
#   'de_ids': [2, 6, 0, 4, 3]},
#  {'en': 'I wept.',
#   'de': 'Ich weinte.',
#   'en_tokens': ['<sos>', 'i', 'wept', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'weinte', '.', '<eos>'],
#   'en_ids': [2, 5, 160, 4, 3],
#   'de_ids': [2, 6, 184, 4, 3]},
#  {'en': 'I wept.',
#   'de': 'Ich habe geweint.',
#   'en_tokens': ['<sos>', 'i', 'wept', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'geweint', '.', '<eos>'],
#   'en_ids': [2, 5, 160, 4, 3],
#   'de_ids': [2, 6, 14, 225, 4, 3]},
#  {'en': "I'm 19.",
#   'de': 'Ich bin 19 Jahre alt.',
#   'en_tokens': ['<sos>', 'i', "'m", '19', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', '19', 'jahre', 'alt', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 164, 4, 3],
#   'de_ids': [2, 6, 8, 0, 0, 117, 4, 3]},
#  {'en': "I'm 19.",
#   'de': 'Ich bin 19.',
#   'en_tokens': ['<sos>', 'i', "'m", '19', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', '19.', '<eos>'],
#   'en_ids': [2, 5, 8, 164, 4, 3],
#   'de_ids': [2, 6, 8, 0, 3]},
#  {'en': "I'm OK.",
#   'de': "Mir geht's gut.",
#   'en_tokens': ['<sos>', 'i', "'m", 'ok', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mir', "geht's", 'gut', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 71, 4, 3],
#   'de_ids': [2, 15, 68, 29, 4, 3]},
#  {'en': "I'm OK.",
#   'de': 'Es geht mir gut.',
#   'en_tokens': ['<sos>', 'i', "'m", 'ok', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'geht', 'mir', 'gut', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 71, 4, 3],
#   'de_ids': [2, 7, 32, 15, 29, 4, 3]},
#  {'en': "I'm up.",
#   'de': 'Ich bin wach.',
#   'en_tokens': ['<sos>', 'i', "'m", 'up', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'wach', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 16, 4, 3],
#   'de_ids': [2, 6, 8, 114, 4, 3]},
#  {'en': "I'm up.",
#   'de': 'Ich bin auf.',
#   'en_tokens': ['<sos>', 'i', "'m", 'up', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'auf', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 16, 4, 3],
#   'de_ids': [2, 6, 8, 19, 4, 3]},
#  {'en': 'Inhale.',
#   'de': 'Einatmen!',
#   'en_tokens': ['<sos>', 'inhale', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'einatmen', '!', '<eos>'],
#   'en_ids': [2, 0, 4, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'Listen.',
#   'de': 'Hört zu.',
#   'en_tokens': ['<sos>', 'listen', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hört', 'zu', '.', '<eos>'],
#   'en_ids': [2, 0, 4, 3],
#   'de_ids': [2, 0, 25, 4, 3]},
#  {'en': 'No way!',
#   'de': 'Unmöglich!',
#   'en_tokens': ['<sos>', 'no', 'way', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'unmöglich', '!', '<eos>'],
#   'en_ids': [2, 59, 90, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'No way!',
#   'de': 'Das kommt nicht in Frage!',
#   'en_tokens': ['<sos>', 'no', 'way', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'das', 'kommt', 'nicht', 'in', 'frage', '!', '<eos>'],
#   'en_ids': [2, 59, 90, 7, 3],
#   'de_ids': [2, 16, 71, 21, 43, 0, 5, 3]},
#  {'en': 'No way!',
#   'de': 'Das gibt’s doch nicht!',
#   'en_tokens': ['<sos>', 'no', 'way', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'das', 'gibt', '’s', 'doch', 'nicht', '!', '<eos>'],
#   'en_ids': [2, 59, 90, 7, 3],
#   'de_ids': [2, 16, 0, 49, 94, 21, 5, 3]},
#  {'en': 'No way!',
#   'de': 'Ausgeschlossen!',
#   'en_tokens': ['<sos>', 'no', 'way', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'ausgeschlossen', '!', '<eos>'],
#   'en_ids': [2, 59, 90, 7, 3],
#   'de_ids': [2, 0, 5, 3]},
#  {'en': 'No way!',
#   'de': 'In keinster Weise!',
#   'en_tokens': ['<sos>', 'no', 'way', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'in', 'keinster', 'weise', '!', '<eos>'],
#   'en_ids': [2, 59, 90, 7, 3],
#   'de_ids': [2, 43, 0, 0, 5, 3]},
#  {'en': 'Really?',
#   'de': 'Wirklich?',
#   'en_tokens': ['<sos>', 'really', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'wirklich', '?', '<eos>'],
#   'en_ids': [2, 149, 14, 3],
#   'de_ids': [2, 0, 13, 3]},
#  {'en': 'Really?',
#   'de': 'Echt?',
#   'en_tokens': ['<sos>', 'really', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'echt', '?', '<eos>'],
#   'en_ids': [2, 149, 14, 3],
#   'de_ids': [2, 0, 13, 3]},
#  {'en': 'Really?',
#   'de': 'Im Ernst?',
#   'en_tokens': ['<sos>', 'really', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'im', 'ernst', '?', '<eos>'],
#   'en_ids': [2, 149, 14, 3],
#   'de_ids': [2, 0, 96, 13, 3]},
#  {'en': 'Thanks!',
#   'de': 'Danke!',
#   'en_tokens': ['<sos>', 'thanks', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'danke', '!', '<eos>'],
#   'en_ids': [2, 242, 7, 3],
#   'de_ids': [2, 195, 5, 3]},
#  {'en': 'Thanks.',
#   'de': 'Danke!',
#   'en_tokens': ['<sos>', 'thanks', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'danke', '!', '<eos>'],
#   'en_ids': [2, 242, 4, 3],
#   'de_ids': [2, 195, 5, 3]},
#  {'en': 'Try it.',
#   'de': 'Versuch’s!',
#   'en_tokens': ['<sos>', 'try', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'versuch', '’s', '!', '<eos>'],
#   'en_ids': [2, 46, 6, 4, 3],
#   'de_ids': [2, 180, 49, 5, 3]},
#  {'en': 'We try.',
#   'de': 'Wir versuchen es.',
#   'en_tokens': ['<sos>', 'we', 'try', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'wir', 'versuchen', 'es', '.', '<eos>'],
#   'en_ids': [2, 37, 46, 4, 3],
#   'de_ids': [2, 34, 283, 7, 4, 3]},
#  {'en': 'We won.',
#   'de': 'Wir haben gewonnen.',
#   'en_tokens': ['<sos>', 'we', 'won', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'wir', 'haben', 'gewonnen', '.', '<eos>'],
#   'en_ids': [2, 37, 53, 4, 3],
#   'de_ids': [2, 34, 69, 37, 4, 3]},
#  {'en': 'Why me?',
#   'de': 'Warum ich?',
#   'en_tokens': ['<sos>', 'why', 'me', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'warum', 'ich', '?', '<eos>'],
#   'en_ids': [2, 0, 15, 14, 3],
#   'de_ids': [2, 0, 6, 13, 3]},
#  {'en': 'Am I OK?',
#   'de': 'Ist mit mir alles in Ordnung?',
#   'en_tokens': ['<sos>', 'am', 'i', 'ok', '?', '<eos>'],
#   'de_tokens': ['<sos>',
#    'ist',
#    'mit',
#    'mir',
#    'alles',
#    'in',
#    'ordnung',
#    '?',
#    '<eos>'],
#   'en_ids': [2, 22, 5, 71, 14, 3],
#   'de_ids': [2, 11, 74, 15, 0, 43, 154, 13, 3]},
#  {'en': 'Ask Tom.',
#   'de': 'Frag Tom!',
#   'en_tokens': ['<sos>', 'ask', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'frag', 'tom', '!', '<eos>'],
#   'en_ids': [2, 41, 9, 4, 3],
#   'de_ids': [2, 66, 9, 5, 3]},
#  {'en': 'Ask Tom.',
#   'de': 'Fragen Sie Tom!',
#   'en_tokens': ['<sos>', 'ask', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'fragen', 'sie', 'tom', '!', '<eos>'],
#   'en_ids': [2, 41, 9, 4, 3],
#   'de_ids': [2, 209, 10, 9, 5, 3]},
#  {'en': 'Ask Tom.',
#   'de': 'Fragt Tom!',
#   'en_tokens': ['<sos>', 'ask', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'fragt', 'tom', '!', '<eos>'],
#   'en_ids': [2, 41, 9, 4, 3],
#   'de_ids': [2, 210, 9, 5, 3]},
#  {'en': 'Ask Tom.',
#   'de': 'Frag Tom.',
#   'en_tokens': ['<sos>', 'ask', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'frag', 'tom', '.', '<eos>'],
#   'en_ids': [2, 41, 9, 4, 3],
#   'de_ids': [2, 66, 9, 4, 3]},
#  {'en': 'Awesome!',
#   'de': 'Fantastisch!',
#   'en_tokens': ['<sos>', 'awesome', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'fantastisch', '!', '<eos>'],
#   'en_ids': [2, 0, 7, 3],
#   'de_ids': [2, 203, 5, 3]},
#  {'en': 'Be cool.',
#   'de': 'Entspann dich!',
#   'en_tokens': ['<sos>', 'be', 'cool', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'entspann', 'dich', '!', '<eos>'],
#   'en_ids': [2, 20, 74, 4, 3],
#   'de_ids': [2, 130, 12, 5, 3]},
#  {'en': 'Be fair.',
#   'de': 'Sei nicht ungerecht!',
#   'en_tokens': ['<sos>', 'be', 'fair', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'sei', 'nicht', 'ungerecht', '!', '<eos>'],
#   'en_ids': [2, 20, 95, 4, 3],
#   'de_ids': [2, 44, 21, 0, 5, 3]},
#  {'en': 'Be fair.',
#   'de': 'Sei fair!',
#   'en_tokens': ['<sos>', 'be', 'fair', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'sei', 'fair', '!', '<eos>'],
#   'en_ids': [2, 20, 95, 4, 3],
#   'de_ids': [2, 44, 0, 5, 3]},
#  {'en': 'Be kind.',
#   'de': 'Sei nett!',
#   'en_tokens': ['<sos>', 'be', 'kind', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'sei', 'nett', '!', '<eos>'],
#   'en_ids': [2, 20, 0, 4, 3],
#   'de_ids': [2, 44, 152, 5, 3]},
#  {'en': 'Be nice.',
#   'de': 'Sei nett!',
#   'en_tokens': ['<sos>', 'be', 'nice', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'sei', 'nett', '!', '<eos>'],
#   'en_ids': [2, 20, 145, 4, 3],
#   'de_ids': [2, 44, 152, 5, 3]},
#  {'en': 'Be nice.',
#   'de': 'Seien Sie nett!',
#   'en_tokens': ['<sos>', 'be', 'nice', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'seien', 'sie', 'nett', '!', '<eos>'],
#   'en_ids': [2, 20, 145, 4, 3],
#   'de_ids': [2, 165, 10, 152, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Geh weg!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'weg', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 27, 30, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Hau ab!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hau', 'ab', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 70, 23, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Verschwinde!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verschwinde', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 84, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Verdufte!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verdufte', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 82, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Mach dich fort!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'dich', 'fort', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 17, 12, 36, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Zieh Leine!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'zieh', 'leine', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 61, 73, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Mach dich vom Acker!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'dich', 'vom', 'acker', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 17, 12, 86, 62, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Verzieh dich!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verzieh', 'dich', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 85, 12, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Verkrümele dich!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verkrümele', 'dich', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 83, 12, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Troll dich!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'troll', 'dich', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 80, 12, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Zisch ab!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'zisch', 'ab', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 91, 23, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Pack dich!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'pack', 'dich', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 75, 12, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Mach ’ne Fliege!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', '’ne', 'fliege', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 17, 92, 65, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Schwirr ab!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'schwirr', 'ab', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 78, 23, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Mach die Sause!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'die', 'sause', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 17, 41, 76, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Scher dich weg!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'scher', 'dich', 'weg', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 39, 12, 30, 5, 3]},
#  {'en': 'Beat it.',
#   'de': 'Scher dich fort!',
#   'en_tokens': ['<sos>', 'beat', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'scher', 'dich', 'fort', '!', '<eos>'],
#   'en_ids': [2, 23, 6, 4, 3],
#   'de_ids': [2, 39, 12, 36, 5, 3]},
#  {'en': 'Burn it.',
#   'de': 'Verbrenne es!',
#   'en_tokens': ['<sos>', 'burn', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verbrenne', 'es', '!', '<eos>'],
#   'en_ids': [2, 124, 6, 4, 3],
#   'de_ids': [2, 0, 7, 5, 3]},
#  {'en': 'Burn it.',
#   'de': 'Verbrennt es!',
#   'en_tokens': ['<sos>', 'burn', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verbrennt', 'es', '!', '<eos>'],
#   'en_ids': [2, 124, 6, 4, 3],
#   'de_ids': [2, 0, 7, 5, 3]},
#  {'en': 'Burn it.',
#   'de': 'Verbrennen Sie es!',
#   'en_tokens': ['<sos>', 'burn', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verbrennen', 'sie', 'es', '!', '<eos>'],
#   'en_ids': [2, 124, 6, 4, 3],
#   'de_ids': [2, 0, 10, 7, 5, 3]},
#  {'en': 'Bury it.',
#   'de': 'Vergrabe es!',
#   'en_tokens': ['<sos>', 'bury', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'vergrabe', 'es', '!', '<eos>'],
#   'en_ids': [2, 0, 6, 4, 3],
#   'de_ids': [2, 0, 7, 5, 3]},
#  {'en': 'Call me.',
#   'de': 'Ruf mich an.',
#   'en_tokens': ['<sos>', 'call', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ruf', 'mich', 'an', '.', '<eos>'],
#   'en_ids': [2, 47, 15, 4, 3],
#   'de_ids': [2, 161, 18, 35, 4, 3]},
#  {'en': 'Come in.',
#   'de': 'Komm herein.',
#   'en_tokens': ['<sos>', 'come', 'in', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'komm', 'herein', '.', '<eos>'],
#   'en_ids': [2, 24, 50, 4, 3],
#   'de_ids': [2, 33, 141, 4, 3]},
#  {'en': 'Come in.',
#   'de': 'Herein!',
#   'en_tokens': ['<sos>', 'come', 'in', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'herein', '!', '<eos>'],
#   'en_ids': [2, 24, 50, 4, 3],
#   'de_ids': [2, 141, 5, 3]},
#  {'en': 'Come on!',
#   'de': 'Komm!',
#   'en_tokens': ['<sos>', 'come', 'on', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'komm', '!', '<eos>'],
#   'en_ids': [2, 24, 40, 7, 3],
#   'de_ids': [2, 33, 5, 3]},
#  {'en': 'Come on!',
#   'de': 'Kommt!',
#   'en_tokens': ['<sos>', 'come', 'on', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'kommt', '!', '<eos>'],
#   'en_ids': [2, 24, 40, 7, 3],
#   'de_ids': [2, 71, 5, 3]},
#  {'en': 'Come on!',
#   'de': 'Mach schon!',
#   'en_tokens': ['<sos>', 'come', 'on', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'schon', '!', '<eos>'],
#   'en_ids': [2, 24, 40, 7, 3],
#   'de_ids': [2, 17, 164, 5, 3]},
#  {'en': 'Come on!',
#   'de': 'Macht schon!',
#   'en_tokens': ['<sos>', 'come', 'on', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'macht', 'schon', '!', '<eos>'],
#   'en_ids': [2, 24, 40, 7, 3],
#   'de_ids': [2, 0, 164, 5, 3]},
#  {'en': 'Come on.',
#   'de': 'Komm schon!',
#   'en_tokens': ['<sos>', 'come', 'on', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'komm', 'schon', '!', '<eos>'],
#   'en_ids': [2, 24, 40, 4, 3],
#   'de_ids': [2, 33, 164, 5, 3]},
#  {'en': 'Drop it!',
#   'de': 'Lasst es fallen!',
#   'en_tokens': ['<sos>', 'drop', 'it', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'lasst', 'es', 'fallen', '!', '<eos>'],
#   'en_ids': [2, 130, 6, 7, 3],
#   'de_ids': [2, 107, 7, 131, 5, 3]},
#  {'en': 'Drop it!',
#   'de': 'Fallen lassen!',
#   'en_tokens': ['<sos>', 'drop', 'it', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'fallen', 'lassen', '!', '<eos>'],
#   'en_ids': [2, 130, 6, 7, 3],
#   'de_ids': [2, 131, 145, 5, 3]},
#  {'en': 'Drop it.',
#   'de': 'Fallen lassen!',
#   'en_tokens': ['<sos>', 'drop', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'fallen', 'lassen', '!', '<eos>'],
#   'en_ids': [2, 130, 6, 4, 3],
#   'de_ids': [2, 131, 145, 5, 3]},
#  {'en': 'Fold it.',
#   'de': 'Falte es zusammen!',
#   'en_tokens': ['<sos>', 'fold', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'falte', 'es', 'zusammen', '!', '<eos>'],
#   'en_ids': [2, 0, 6, 4, 3],
#   'de_ids': [2, 0, 7, 0, 5, 3]},
#  {'en': 'Get Tom.',
#   'de': 'Hol Tom.',
#   'en_tokens': ['<sos>', 'get', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hol', 'tom', '.', '<eos>'],
#   'en_ids': [2, 11, 9, 4, 3],
#   'de_ids': [2, 143, 9, 4, 3]},
#  {'en': 'Get out!',
#   'de': 'Raus!',
#   'en_tokens': ['<sos>', 'get', 'out', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'raus', '!', '<eos>'],
#   'en_ids': [2, 11, 45, 7, 3],
#   'de_ids': [2, 111, 5, 3]},
#  {'en': 'Get out!',
#   'de': 'Geht raus!',
#   'en_tokens': ['<sos>', 'get', 'out', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'geht', 'raus', '!', '<eos>'],
#   'en_ids': [2, 11, 45, 7, 3],
#   'de_ids': [2, 32, 111, 5, 3]},
#  {'en': 'Get out.',
#   'de': 'Geh raus.',
#   'en_tokens': ['<sos>', 'get', 'out', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'raus', '.', '<eos>'],
#   'en_ids': [2, 11, 45, 4, 3],
#   'de_ids': [2, 27, 111, 4, 3]},
#  {'en': 'Get out.',
#   'de': 'Geht raus!',
#   'en_tokens': ['<sos>', 'get', 'out', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geht', 'raus', '!', '<eos>'],
#   'en_ids': [2, 11, 45, 4, 3],
#   'de_ids': [2, 32, 111, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Geh weg!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'weg', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 27, 30, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Hau ab!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'hau', 'ab', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 70, 23, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Verschwinde!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'verschwinde', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 84, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Verdufte!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'verdufte', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 82, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Mach dich fort!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'dich', 'fort', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 17, 12, 36, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Zieh Leine!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'zieh', 'leine', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 61, 73, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Mach dich vom Acker!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'dich', 'vom', 'acker', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 17, 12, 86, 62, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Verzieh dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'verzieh', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 85, 12, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Verkrümele dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'verkrümele', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 83, 12, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Troll dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'troll', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 80, 12, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Zisch ab!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'zisch', 'ab', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 91, 23, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Pack dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'pack', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 75, 12, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Mach ’ne Fliege!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', '’ne', 'fliege', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 17, 92, 65, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Schwirr ab!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'schwirr', 'ab', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 78, 23, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Mach die Sause!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'die', 'sause', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 17, 41, 76, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Scher dich weg!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'scher', 'dich', 'weg', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 39, 12, 30, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Scher dich fort!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'scher', 'dich', 'fort', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 39, 12, 36, 5, 3]},
#  {'en': 'Go away!',
#   'de': 'Gehen Sie weg!',
#   'en_tokens': ['<sos>', 'go', 'away', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'gehen', 'sie', 'weg', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 7, 3],
#   'de_ids': [2, 31, 10, 30, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Geh weg!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'weg', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 27, 30, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Verpiss dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verpiss', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 175, 12, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Hau ab!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hau', 'ab', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 70, 23, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Verschwinde!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verschwinde', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 84, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Verdufte!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verdufte', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 82, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Mach dich fort!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'dich', 'fort', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 17, 12, 36, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Zieh Leine!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'zieh', 'leine', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 61, 73, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Mach dich vom Acker!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'dich', 'vom', 'acker', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 17, 12, 86, 62, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Verzieh dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verzieh', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 85, 12, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Verkrümele dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'verkrümele', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 83, 12, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Troll dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'troll', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 80, 12, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Zisch ab!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'zisch', 'ab', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 91, 23, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Pack dich!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'pack', 'dich', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 75, 12, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Mach ’ne Fliege!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', '’ne', 'fliege', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 17, 92, 65, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Schwirr ab!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'schwirr', 'ab', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 78, 23, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Mach die Sause!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'mach', 'die', 'sause', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 17, 41, 76, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Scher dich weg!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'scher', 'dich', 'weg', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 39, 12, 30, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Scher dich fort!',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'scher', 'dich', 'fort', '!', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 39, 12, 36, 5, 3]},
#  {'en': 'Go away.',
#   'de': 'Gehen Sie weg.',
#   'en_tokens': ['<sos>', 'go', 'away', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'gehen', 'sie', 'weg', '.', '<eos>'],
#   'en_ids': [2, 10, 12, 4, 3],
#   'de_ids': [2, 31, 10, 30, 4, 3]},
#  {'en': 'Go home.',
#   'de': 'Geh nach Hause.',
#   'en_tokens': ['<sos>', 'go', 'home', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'nach', 'hause', '.', '<eos>'],
#   'en_ids': [2, 10, 57, 4, 3],
#   'de_ids': [2, 27, 108, 232, 4, 3]},
#  {'en': 'Go home.',
#   'de': 'Geh heim.',
#   'en_tokens': ['<sos>', 'go', 'home', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'geh', 'heim', '.', '<eos>'],
#   'en_ids': [2, 10, 57, 4, 3],
#   'de_ids': [2, 27, 140, 4, 3]},
#  {'en': 'Goodbye!',
#   'de': 'Auf Wiedersehen!',
#   'en_tokens': ['<sos>', 'goodbye', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'auf', 'wiedersehen', '!', '<eos>'],
#   'en_ids': [2, 97, 7, 3],
#   'de_ids': [2, 19, 292, 5, 3]},
#  {'en': 'Goodbye!',
#   'de': 'Leb wohl!',
#   'en_tokens': ['<sos>', 'goodbye', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'leb', 'wohl', '!', '<eos>'],
#   'en_ids': [2, 97, 7, 3],
#   'de_ids': [2, 0, 294, 5, 3]},
#  {'en': 'Goodbye!',
#   'de': 'Tschüss!',
#   'en_tokens': ['<sos>', 'goodbye', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'tschüss', '!', '<eos>'],
#   'en_ids': [2, 97, 7, 3],
#   'de_ids': [2, 278, 5, 3]},
#  {'en': 'Goodbye.',
#   'de': 'Auf Wiedersehen.',
#   'en_tokens': ['<sos>', 'goodbye', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'auf', 'wiedersehen', '.', '<eos>'],
#   'en_ids': [2, 97, 4, 3],
#   'de_ids': [2, 19, 292, 4, 3]},
#  {'en': 'Hang on!',
#   'de': 'Nicht nachlassen!',
#   'en_tokens': ['<sos>', 'hang', 'on', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'nicht', 'nachlassen', '!', '<eos>'],
#   'en_ids': [2, 198, 40, 7, 3],
#   'de_ids': [2, 21, 0, 5, 3]},
#  {'en': 'Hang on.',
#   'de': 'Warte!',
#   'en_tokens': ['<sos>', 'hang', 'on', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'warte', '!', '<eos>'],
#   'en_ids': [2, 198, 40, 4, 3],
#   'de_ids': [2, 88, 5, 3]},
#  {'en': 'He came.',
#   'de': 'Er kam.',
#   'en_tokens': ['<sos>', 'he', 'came', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'er', 'kam', '.', '<eos>'],
#   'en_ids': [2, 18, 65, 4, 3],
#   'de_ids': [2, 20, 102, 4, 3]},
#  {'en': 'He left.',
#   'de': 'Er ist gegangen.',
#   'en_tokens': ['<sos>', 'he', 'left', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'er', 'ist', 'gegangen', '.', '<eos>'],
#   'en_ids': [2, 18, 103, 4, 3],
#   'de_ids': [2, 20, 11, 134, 4, 3]},
#  {'en': 'He runs.',
#   'de': 'Er rennt.',
#   'en_tokens': ['<sos>', 'he', 'runs', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'er', 'rennt', '.', '<eos>'],
#   'en_ids': [2, 18, 151, 4, 3],
#   'de_ids': [2, 20, 256, 4, 3]},
#  {'en': 'He runs.',
#   'de': 'Er läuft.',
#   'en_tokens': ['<sos>', 'he', 'runs', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'er', 'läuft', '.', '<eos>'],
#   'en_ids': [2, 18, 151, 4, 3],
#   'de_ids': [2, 20, 0, 4, 3]},
#  {'en': 'Help me.',
#   'de': 'Hilf mir.',
#   'en_tokens': ['<sos>', 'help', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hilf', 'mir', '.', '<eos>'],
#   'en_ids': [2, 38, 15, 4, 3],
#   'de_ids': [2, 142, 15, 4, 3]},
#  {'en': 'Help us.',
#   'de': 'Hilf uns!',
#   'en_tokens': ['<sos>', 'help', 'us', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hilf', 'uns', '!', '<eos>'],
#   'en_ids': [2, 38, 21, 4, 3],
#   'de_ids': [2, 142, 22, 5, 3]},
#  {'en': 'Help us.',
#   'de': 'Helft uns!',
#   'en_tokens': ['<sos>', 'help', 'us', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'helft', 'uns', '!', '<eos>'],
#   'en_ids': [2, 38, 21, 4, 3],
#   'de_ids': [2, 234, 22, 5, 3]},
#  {'en': 'Help us.',
#   'de': 'Helfen Sie uns!',
#   'en_tokens': ['<sos>', 'help', 'us', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'helfen', 'sie', 'uns', '!', '<eos>'],
#   'en_ids': [2, 38, 21, 4, 3],
#   'de_ids': [2, 233, 10, 22, 5, 3]},
#  {'en': 'Hi, Tom.',
#   'de': 'Hallo, Tom!',
#   'en_tokens': ['<sos>', 'hi', ',', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'hallo', ',', 'tom', '!', '<eos>'],
#   'en_ids': [2, 141, 91, 9, 4, 3],
#   'de_ids': [2, 99, 53, 9, 5, 3]},
#  {'en': 'Hit Tom.',
#   'de': 'Schlage Tom!',
#   'en_tokens': ['<sos>', 'hit', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'schlage', 'tom', '!', '<eos>'],
#   'en_ids': [2, 56, 9, 4, 3],
#   'de_ids': [2, 262, 9, 5, 3]},
#  {'en': 'Hit Tom.',
#   'de': 'Schlagt Tom!',
#   'en_tokens': ['<sos>', 'hit', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'schlagt', 'tom', '!', '<eos>'],
#   'en_ids': [2, 56, 9, 4, 3],
#   'de_ids': [2, 0, 9, 5, 3]},
#  {'en': 'Hit Tom.',
#   'de': 'Schlagen Sie Tom!',
#   'en_tokens': ['<sos>', 'hit', 'tom', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'schlagen', 'sie', 'tom', '!', '<eos>'],
#   'en_ids': [2, 56, 9, 4, 3],
#   'de_ids': [2, 0, 10, 9, 5, 3]},
#  {'en': 'Hold it!',
#   'de': 'Nicht bewegen!',
#   'en_tokens': ['<sos>', 'hold', 'it', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'nicht', 'bewegen', '!', '<eos>'],
#   'en_ids': [2, 31, 6, 7, 3],
#   'de_ids': [2, 21, 0, 5, 3]},
#  {'en': 'Hold it!',
#   'de': 'Warte!',
#   'en_tokens': ['<sos>', 'hold', 'it', '!', '<eos>'],
# ...
#   'en_ids': [2, 5, 8, 220, 4, 3],
#   'de_ids': [2, 6, 8, 253, 4, 3]},
#  {'en': "I'm picky.",
#   'de': 'Ich bin wählerisch.',
#   'en_tokens': ['<sos>', 'i', "'m", 'picky', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'wählerisch', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 220, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm ready!",
#   'de': 'Ich bin soweit!',
#   'en_tokens': ['<sos>', 'i', "'m", 'ready', '!', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'soweit', '!', '<eos>'],
#   'en_ids': [2, 5, 8, 86, 7, 3],
#   'de_ids': [2, 6, 8, 274, 5, 3]},
#  {'en': "I'm ready.",
#   'de': 'Ich bin soweit.',
#   'en_tokens': ['<sos>', 'i', "'m", 'ready', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'soweit', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 86, 4, 3],
#   'de_ids': [2, 6, 8, 274, 4, 3]},
#  {'en': "I'm ready.",
#   'de': 'Ich bin so weit.',
#   'en_tokens': ['<sos>', 'i', "'m", 'ready', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'so', 'weit', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 86, 4, 3],
#   'de_ids': [2, 6, 8, 273, 290, 4, 3]},
#  {'en': "I'm right.",
#   'de': 'Ich habe recht.',
#   'en_tokens': ['<sos>', 'i', "'m", 'right', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'recht', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 224, 4, 3],
#   'de_ids': [2, 6, 14, 157, 4, 3]},
#  {'en': "I'm right.",
#   'de': 'Ich habe Recht.',
#   'en_tokens': ['<sos>', 'i', "'m", 'right', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'recht', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 224, 4, 3],
#   'de_ids': [2, 6, 14, 157, 4, 3]},
#  {'en': "I'm silly.",
#   'de': 'Ich bin albern.',
#   'en_tokens': ['<sos>', 'i', "'m", 'silly', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'albern', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 231, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm silly.",
#   'de': 'Ich bin dämlich.',
#   'en_tokens': ['<sos>', 'i', "'m", 'silly', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'dämlich', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 231, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm sober.",
#   'de': 'Ich bin nüchtern.',
#   'en_tokens': ['<sos>', 'i', "'m", 'sober', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'nüchtern', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 0, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm sorry.",
#   'de': 'Es tut mir leid.',
#   'en_tokens': ['<sos>', 'i', "'m", 'sorry', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'tut', 'mir', 'leid', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 111, 4, 3],
#   'de_ids': [2, 7, 173, 15, 243, 4, 3]},
#  {'en': "I'm sorry.",
#   'de': 'Entschuldigung!',
#   'en_tokens': ['<sos>', 'i', "'m", 'sorry', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'entschuldigung', '!', '<eos>'],
#   'en_ids': [2, 5, 8, 111, 4, 3],
#   'de_ids': [2, 63, 5, 3]},
#  {'en': "I'm sorry.",
#   'de': 'Entschuldigung.',
#   'en_tokens': ['<sos>', 'i', "'m", 'sorry', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'entschuldigung', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 111, 4, 3],
#   'de_ids': [2, 63, 4, 3]},
#  {'en': "I'm stuck.",
#   'de': 'Ich stecke fest.',
#   'en_tokens': ['<sos>', 'i', "'m", 'stuck', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'stecke', 'fest', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 0, 4, 3],
#   'de_ids': [2, 6, 0, 0, 4, 3]},
#  {'en': "I'm tired.",
#   'de': 'Ich bin müde!',
#   'en_tokens': ['<sos>', 'i', "'m", 'tired', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'müde', '!', '<eos>'],
#   'en_ids': [2, 5, 8, 244, 4, 3],
#   'de_ids': [2, 6, 8, 249, 5, 3]},
#  {'en': "I'm tired.",
#   'de': 'Ich bin müde.',
#   'en_tokens': ['<sos>', 'i', "'m", 'tired', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'müde', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 244, 4, 3],
#   'de_ids': [2, 6, 8, 249, 4, 3]},
#  {'en': "I'm tough.",
#   'de': 'Ich bin zäh.',
#   'en_tokens': ['<sos>', 'i', "'m", 'tough', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'zäh', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 0, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm upset.",
#   'de': 'Ich bin verärgert.',
#   'en_tokens': ['<sos>', 'i', "'m", 'upset', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'verärgert', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 247, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm upset.",
#   'de': 'Ich bin bestürzt.',
#   'en_tokens': ['<sos>', 'i', "'m", 'upset', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'bin', 'bestürzt', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 247, 4, 3],
#   'de_ids': [2, 6, 8, 0, 4, 3]},
#  {'en': "I'm wrong.",
#   'de': 'Ich habe mich geirrt.',
#   'en_tokens': ['<sos>', 'i', "'m", 'wrong', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'mich', 'geirrt', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 260, 4, 3],
#   'de_ids': [2, 6, 14, 18, 0, 4, 3]},
#  {'en': "I'm wrong.",
#   'de': 'Ich liege falsch.',
#   'en_tokens': ['<sos>', 'i', "'m", 'wrong', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'liege', 'falsch', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 260, 4, 3],
#   'de_ids': [2, 6, 0, 0, 4, 3]},
#  {'en': "I'm yours.",
#   'de': 'Ich gehöre dir.',
#   'en_tokens': ['<sos>', 'i', "'m", 'yours', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'gehöre', 'dir', '.', '<eos>'],
#   'en_ids': [2, 5, 8, 0, 4, 3],
#   'de_ids': [2, 6, 0, 46, 4, 3]},
#  {'en': "I've lost.",
#   'de': 'Ich habe verloren.',
#   'en_tokens': ['<sos>', 'i', "'ve", 'lost', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'ich', 'habe', 'verloren', '.', '<eos>'],
#   'en_ids': [2, 5, 0, 17, 4, 3],
#   'de_ids': [2, 6, 14, 45, 4, 3]},
#  {'en': 'Ignore it.',
#   'de': 'Beachte es gar nicht!',
#   'en_tokens': ['<sos>', 'ignore', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'beachte', 'es', 'gar', 'nicht', '!', '<eos>'],
#   'en_ids': [2, 206, 6, 4, 3],
#   'de_ids': [2, 0, 7, 214, 21, 5, 3]},
#  {'en': 'Ignore it.',
#   'de': 'Beachten Sie es gar nicht!',
#   'en_tokens': ['<sos>', 'ignore', 'it', '.', '<eos>'],
#   'de_tokens': ['<sos>',
#    'beachten',
#    'sie',
#    'es',
#    'gar',
#    'nicht',
#    '!',
#    '<eos>'],
#   'en_ids': [2, 206, 6, 4, 3],
#   'de_ids': [2, 0, 10, 7, 214, 21, 5, 3]},
#  {'en': 'Is Tom OK?',
#   'de': 'Ist Tom okay?',
#   'en_tokens': ['<sos>', 'is', 'tom', 'ok', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'tom', 'okay', '?', '<eos>'],
#   'en_ids': [2, 28, 9, 71, 14, 3],
#   'de_ids': [2, 11, 9, 0, 13, 3]},
#  {'en': 'Is Tom in?',
#   'de': 'Ist Tom da?',
#   'en_tokens': ['<sos>', 'is', 'tom', 'in', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'tom', 'da', '?', '<eos>'],
#   'en_ids': [2, 28, 9, 50, 14, 3],
#   'de_ids': [2, 11, 9, 93, 13, 3]},
#  {'en': 'Is he Tom?',
#   'de': 'Ist das Tom?',
#   'en_tokens': ['<sos>', 'is', 'he', 'tom', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'das', 'tom', '?', '<eos>'],
#   'en_ids': [2, 28, 18, 9, 14, 3],
#   'de_ids': [2, 11, 16, 9, 13, 3]},
#  {'en': 'Is he Tom?',
#   'de': 'Ist er Tom?',
#   'en_tokens': ['<sos>', 'is', 'he', 'tom', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'er', 'tom', '?', '<eos>'],
#   'en_ids': [2, 28, 18, 9, 14, 3],
#   'de_ids': [2, 11, 20, 9, 13, 3]},
#  {'en': 'Is it Tom?',
#   'de': 'Ist das Tom?',
#   'en_tokens': ['<sos>', 'is', 'it', 'tom', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'das', 'tom', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 9, 14, 3],
#   'de_ids': [2, 11, 16, 9, 13, 3]},
#  {'en': 'Is it bad?',
#   'de': 'Ist es schlimm?',
#   'en_tokens': ['<sos>', 'is', 'it', 'bad', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'es', 'schlimm', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 122, 14, 3],
#   'de_ids': [2, 11, 7, 0, 13, 3]},
#  {'en': 'Is it bad?',
#   'de': 'Ist es schlecht?',
#   'en_tokens': ['<sos>', 'is', 'it', 'bad', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'es', 'schlecht', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 122, 14, 3],
#   'de_ids': [2, 11, 7, 163, 13, 3]},
#  {'en': 'Is it far?',
#   'de': 'Ist das weit?',
#   'en_tokens': ['<sos>', 'is', 'it', 'far', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'das', 'weit', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 0, 14, 3],
#   'de_ids': [2, 11, 16, 290, 13, 3]},
#  {'en': 'Is it hot?',
#   'de': 'Ist es heiß?',
#   'en_tokens': ['<sos>', 'is', 'it', 'hot', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'es', 'heiß', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 70, 14, 3],
#   'de_ids': [2, 11, 7, 57, 13, 3]},
#  {'en': 'Is it new?',
#   'de': 'Ist es neu?',
#   'en_tokens': ['<sos>', 'is', 'it', 'new', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'es', 'neu', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 105, 14, 3],
#   'de_ids': [2, 11, 7, 109, 13, 3]},
#  {'en': 'Is it red?',
#   'de': 'Ist es rot?',
#   'en_tokens': ['<sos>', 'is', 'it', 'red', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'es', 'rot', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 150, 14, 3],
#   'de_ids': [2, 11, 7, 160, 13, 3]},
#  {'en': 'Is it red?',
#   'de': 'Ist sie rot?',
#   'en_tokens': ['<sos>', 'is', 'it', 'red', '?', '<eos>'],
#   'de_tokens': ['<sos>', 'ist', 'sie', 'rot', '?', '<eos>'],
#   'en_ids': [2, 28, 6, 150, 14, 3],
#   'de_ids': [2, 11, 10, 160, 13, 3]},
#  {'en': 'It bit me.',
#   'de': 'Sie hat mich gebissen.',
#   'en_tokens': ['<sos>', 'it', 'bit', 'me', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'sie', 'hat', 'mich', 'gebissen', '.', '<eos>'],
#   'en_ids': [2, 6, 0, 15, 4, 3],
#   'de_ids': [2, 10, 26, 18, 0, 4, 3]},
#  {'en': 'It burned.',
#   'de': 'Es brannte.',
#   'en_tokens': ['<sos>', 'it', 'burned', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'brannte', '.', '<eos>'],
#   'en_ids': [2, 6, 173, 4, 3],
#   'de_ids': [2, 7, 0, 4, 3]},
#  {'en': 'It burned.',
#   'de': 'Es verbrannte.',
#   'en_tokens': ['<sos>', 'it', 'burned', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'verbrannte', '.', '<eos>'],
#   'en_ids': [2, 6, 173, 4, 3],
#   'de_ids': [2, 7, 0, 4, 3]},
#  {'en': 'It poured.',
#   'de': 'Es schüttete.',
#   'en_tokens': ['<sos>', 'it', 'poured', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'schüttete', '.', '<eos>'],
#   'en_ids': [2, 6, 0, 4, 3],
#   'de_ids': [2, 7, 0, 4, 3]},
#  {'en': 'It snowed.',
#   'de': 'Es hat geschneit.',
#   'en_tokens': ['<sos>', 'it', 'snowed', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'hat', 'geschneit', '.', '<eos>'],
#   'en_ids': [2, 6, 0, 4, 3],
#   'de_ids': [2, 7, 26, 0, 4, 3]},
#  {'en': 'It stinks.',
#   'de': 'Da ist doch was faul.',
#   'en_tokens': ['<sos>', 'it', 'stinks', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'da', 'ist', 'doch', 'was', 'faul', '.', '<eos>'],
#   'en_ids': [2, 6, 0, 4, 3],
#   'de_ids': [2, 93, 11, 94, 89, 0, 4, 3]},
#  {'en': 'It worked.',
#   'de': 'Es hat geklappt.',
#   'en_tokens': ['<sos>', 'it', 'worked', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'hat', 'geklappt', '.', '<eos>'],
#   'en_ids': [2, 6, 257, 4, 3],
#   'de_ids': [2, 7, 26, 0, 4, 3]},
#  {'en': 'It worked.',
#   'de': 'Das hat funktioniert.',
#   'en_tokens': ['<sos>', 'it', 'worked', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'das', 'hat', 'funktioniert', '.', '<eos>'],
#   'en_ids': [2, 6, 257, 4, 3],
#   'de_ids': [2, 16, 26, 212, 4, 3]},
#  {'en': "It's 3:30.",
#   'de': 'Es ist halb vier.',
#   'en_tokens': ['<sos>', 'it', "'s", '3:30', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'halb', 'vier', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 0, 4, 3],
#   'de_ids': [2, 7, 11, 0, 0, 4, 3]},
#  {'en': "It's 7:45.",
#   'de': 'Es ist 7:45 Uhr.',
#   'en_tokens': ['<sos>', 'it', "'s", '7:45', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', '7:45', 'uhr', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 165, 4, 3],
#   'de_ids': [2, 7, 11, 0, 81, 4, 3]},
#  {'en': "It's 7:45.",
#   'de': 'Es ist sieben Uhr fünfundvierzig.',
#   'en_tokens': ['<sos>', 'it', "'s", '7:45', '.', '<eos>'],
#   'de_tokens': ['<sos>',
#    'es',
#    'ist',
#    'sieben',
#    'uhr',
#    'fünfundvierzig',
#    '.',
#    '<eos>'],
#   'en_ids': [2, 6, 13, 165, 4, 3],
#   'de_ids': [2, 7, 11, 0, 81, 0, 4, 3]},
#  {'en': "It's 8:30.",
#   'de': 'Es ist 8:30 Uhr.',
#   'en_tokens': ['<sos>', 'it', "'s", '8:30', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', '8:30', 'uhr', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 166, 4, 3],
#   'de_ids': [2, 7, 11, 0, 81, 4, 3]},
#  {'en': "It's 8:30.",
#   'de': 'Es ist jetzt 8.30 Uhr.',
#   'en_tokens': ['<sos>', 'it', "'s", '8:30', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'jetzt', '8.30', 'uhr', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 166, 4, 3],
#   'de_ids': [2, 7, 11, 51, 0, 81, 4, 3]},
#  {'en': "It's 9:15.",
#   'de': 'Es ist Viertel nach neun.',
#   'en_tokens': ['<sos>', 'it', "'s", '9:15', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'viertel', 'nach', 'neun', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 167, 4, 3],
#   'de_ids': [2, 7, 11, 0, 108, 0, 4, 3]},
#  {'en': "It's 9:15.",
#   'de': 'Es ist 9.15\xa0Uhr.',
#   'en_tokens': ['<sos>', 'it', "'s", '9:15', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', '9.15', '\xa0', 'uhr', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 167, 4, 3],
#   'de_ids': [2, 7, 11, 0, 0, 81, 4, 3]},
#  {'en': "It's a TV.",
#   'de': 'Das ist ein Fernseher.',
#   'en_tokens': ['<sos>', 'it', "'s", 'a', 'tv', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'das', 'ist', 'ein', 'fernseher', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 34, 0, 4, 3],
#   'de_ids': [2, 16, 11, 55, 0, 4, 3]},
#  {'en': "It's cold.",
#   'de': 'Es ist kalt.',
#   'en_tokens': ['<sos>', 'it', "'s", 'cold', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'kalt', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 0, 4, 3],
#   'de_ids': [2, 7, 11, 0, 4, 3]},
#  {'en': "It's cool.",
#   'de': 'Es ist kühl.',
#   'en_tokens': ['<sos>', 'it', "'s", 'cool', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'kühl', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 74, 4, 3],
#   'de_ids': [2, 7, 11, 0, 4, 3]},
#  {'en': "It's dark.",
#   'de': 'Es ist dunkel.',
#   'en_tokens': ['<sos>', 'it', "'s", 'dark', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'dunkel', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 0, 4, 3],
#   'de_ids': [2, 7, 11, 0, 4, 3]},
#  {'en': "It's easy.",
#   'de': 'Das ist einfach.',
#   'en_tokens': ['<sos>', 'it', "'s", 'easy', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'das', 'ist', 'einfach', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 182, 4, 3],
#   'de_ids': [2, 16, 11, 198, 4, 3]},
#  {'en': "It's easy.",
#   'de': 'Es ist einfach.',
#   'en_tokens': ['<sos>', 'it', "'s", 'easy', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'einfach', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 182, 4, 3],
#   'de_ids': [2, 7, 11, 198, 4, 3]},
#  {'en': "It's fair.",
#   'de': 'Es ist gerecht.',
#   'en_tokens': ['<sos>', 'it', "'s", 'fair', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'gerecht', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 95, 4, 3],
#   'de_ids': [2, 7, 11, 220, 4, 3]},
#  {'en': "It's free.",
#   'de': 'Es ist frei.',
#   'en_tokens': ['<sos>', 'it', "'s", 'free', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'frei', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 190, 4, 3],
#   'de_ids': [2, 7, 11, 211, 4, 3]},
#  {'en': "It's full.",
#   'de': 'Es ist voll.',
#   'en_tokens': ['<sos>', 'it', "'s", 'full', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'voll', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 193, 4, 3],
#   'de_ids': [2, 7, 11, 0, 4, 3]},
#  {'en': "It's gone.",
#   'de': 'Es ist verschwunden.',
#   'en_tokens': ['<sos>', 'it', "'s", 'gone', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'verschwunden', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 196, 4, 3],
#   'de_ids': [2, 7, 11, 0, 4, 3]},
#  {'en': "It's gone.",
#   'de': 'Es ist weg.',
#   'en_tokens': ['<sos>', 'it', "'s", 'gone', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'weg', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 196, 4, 3],
#   'de_ids': [2, 7, 11, 30, 4, 3]},
#  {'en': "It's hard.",
#   'de': 'Das ist hart.',
#   'en_tokens': ['<sos>', 'it', "'s", 'hard', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'das', 'ist', 'hart', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 200, 4, 3],
#   'de_ids': [2, 16, 11, 0, 4, 3]},
#  {'en': "It's here.",
#   'de': 'Es ist hier.',
#   'en_tokens': ['<sos>', 'it', "'s", 'here', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'hier', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 49, 4, 3],
#   'de_ids': [2, 7, 11, 58, 4, 3]},
#  {'en': "It's late.",
#   'de': 'Es ist spät.',
#   'en_tokens': ['<sos>', 'it', "'s", 'late', '.', '<eos>'],
#   'de_tokens': ['<sos>', 'es', 'ist', 'spät', '.', '<eos>'],
#   'en_ids': [2, 6, 13, 102, 4, 3],
#   'de_ids': [2, 7, 11, 113, 4, 3]}]

# %% [markdown]
# L'equivalència del tokens i index és correcte

# %%
print(train[100]["en_tokens"])
print(en_vocab.lookup_tokens(train[100]["en_ids"]))
train[100]["en_tokens"] == en_vocab.lookup_tokens(train[100]["en_ids"])
# Out:
# ['<sos>', 'no', 'way', '!', '<eos>']
# ['<sos>', 'no', 'way', '!', '<eos>']
# True
